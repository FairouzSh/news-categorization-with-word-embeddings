# %% [markdown]
# # Text Classification
# ## This notebook outlines the usage of NLP Feature extraction (CountVectorizer, TfidfVectorizer, word2vec, doc2vec) in classification of text documents

# %% [markdown]
# ### Import all the necessary libraries

# %%
from pprint import pprint
from time import time
import logging

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from pprint import pprint
import pandas as pd

# %% [markdown]
# ### Fetch documents for these 2 categories

# %%
# Load some categories from the training set
categories = [
    'alt.atheism',
    'talk.religion.misc',
]

# %%
print("Loading 20 newsgroups dataset for categories:")
print(categories)
# Out:
# Loading 20 newsgroups dataset for categories:
# ['alt.atheism', 'talk.religion.misc']

# %%
train_data = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'), categories=categories)
print(f"{len(train_data.filenames)} documents")
print(f"{len(train_data.target_names)} categories")
print()
# Out:
# 857 documents
# 2 categories

# %%
type(train_data.data)
# Out:
# list

# %%
train_data.target_names
# Out:
# ['alt.atheism', 'talk.religion.misc']

# %%
train_df = pd.DataFrame([train_data.data, train_data.target.tolist()]).T
train_df.columns = ['text', 'target']
train_df.head(20)
# Out:
#                                                  text target
# 0   Benedikt Rosenau writes, with great authority:...      0
# 1   \n[...stuff deleted...]\n\nComputers are an ex...      0
# 2   \n[deletia]\n\n\n      In the deletions somewh...      0
# 3   ...\n\n\tBefore or after his kids were shot?\n...      1
# 4                                                  \n      1
# 5    \n(Deletion)\n \nNo cookies, Charlie. The cla...      0
# 6    \n(Deletion)\n \nNo it in the way it is usual...      0
# 7   \n\n[...stiff deleted...]\n\n\n[...stiff delet...      1
# 8   (excess stuff deleted...)\n\n    \n\nI know of...      0
# 9   [deletions]\n[deletions]\n\n As you have prese...      0
# 10  \n   I'm sorry, I thought we were discussing h...      1
# 11  \nSo that still leaves the door totally open f...      0
# 12  \n: When the object of their belief is said to...      0
# 13  \n\n\n\nIt is good to remember that every tran...      0
# 14  \n: Upon arriving at home, Joseph probably too...      0
# 15  iank@microsoft.com (Ian Kennedy) writes...\n\n...      1
# 16  \n\nWell, there is a fair amount of evidence f...      1
# 17  \nRef: Encyclopedia of Religion, Mircea Eliade...      1
# 18  In <lsran6INN14a@exodus.Eng.Sun.COM> emarsh@he...      0
# 19  \nNot entirely.  Its not a premise, its a conc...      1

# %%
test_data = fetch_20newsgroups(subset='test',
                                    remove=('headers', 'footers', 'quotes'),
                                    categories=categories)
len(test_data.target)
# Out:
# 570

# %%
test_df = pd.DataFrame([test_data.data, test_data.target.tolist()]).T
test_df.columns = ['text', 'target']
test_df.head(20)
# Out:
#                                                  text target
# 0   \nThrow away the FAQ.   We can all just ask Mr...      0
# 1   : At the risk of beginning a cascade, I'll sta...      0
# 2   \n: But how do we know that you're representin...      0
# 3   \n  Thanks for the etymology lesson, but I act...      1
# 4   \n\n\n\nI think this should be illuminating to...      0
# 5   \n\n\n\n\nBzzt. Thank you for playing.\n\nYou'...      1
# 6   \n\nNo.  Zeno's paradox is resolved by showing...      1
# 7   \nYou can tell your friend from me that I was ...      0
# 8      \nJesus did and so do I.\n\nPeace be with you,      1
# 9   In the King James Version of the Bible there a...      1
# 10                                                         0
# 11  \n\n\tMore to the point, how long are atheists...      0
# 12  \nThis all would also implicate that in order ...      1
# 13  \nIf the children are not being fed, whose fau...      1
# 14  \nWhat I mean is what I said.   "What I want" ...      0
# 15  \nWell, where is he?  Another false Messiah sh...      1
# 16  \nGreat start.  I realize immediately that you...      0
# 17  KS> This is the story of Kent, the archetype F...      0
# 18  With the Southern Baptist Convention convening...      0
# 19  \nProve it.  I am an atheist.  It doesn't mean...      0

# %% [markdown]
# ### Preprocess the text

# %%
import re
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
import gensim
from gensim.utils import simple_preprocess

nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('stopwords')

STOPWORDS = set(stopwords.words('english'))
STOPWORDS.update(["github", "action", "pull", "request"])

lemmatizer = WordNetLemmatizer()
wordnet_map = {"N": wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess(df):
    
    def remove_urls(text):
        url_pattern = re.compile(r'https?://\S+|www\.\S+')
        return url_pattern.sub(r'', text)

    # Reference : https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b
    def remove_emoji(text):
        emoji_pattern = re.compile("["
                                   u"\U0001F600-\U0001F64F"  # emoticons
                                   u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                                   u"\U0001F680-\U0001F6FF"  # transport & map symbols
                                   u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                                   u"\U00002702-\U000027B0"
                                   u"\U000024C2-\U0001F251"
                                   "]+", flags=re.UNICODE)
        return emoji_pattern.sub(r'', text)

    def remove_html(text):
        html_pattern = re.compile('<.*?>')
        return html_pattern.sub(r'', text)

    def remove_punctuation(text):
        return text.translate(str.maketrans('', '', '!"#$%&\'()*+,./:;<=>?@[\]^_`{|}~'))

    def remove_digits(text):
        return text.translate(str.maketrans('', '', string.digits))

    def lemmatize_words(text):
        pos_tagged_text = nltk.pos_tag(text.split())
        return " ".join(
            [lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.NOUN)) for word, pos in pos_tagged_text])

    def remove_stopwords(text):
        return " ".join([word for word in str(text).split() if word not in STOPWORDS])
    

    df = df.str.lower()  # lowercase
    df = df.apply(lambda text: remove_urls(text))  # remove urls
    df = df.apply(lambda text: remove_emoji(text))  # remove emojis
    df = df.apply(lambda text: remove_html(text))  # remove html
    df = df.apply(lambda text: remove_punctuation(text))  # remove punctuation
    #df = df.apply(lambda text: remove_digits(text))  # remove digits
    df = df.apply(lambda text: remove_stopwords(text))  # remove stopwords
    df = df.apply(lambda text: lemmatize_words(text))  # lemmatize
    #df = df.apply(lambda text: nltk.word_tokenize(text))

    return df

# %%
train_processed = preprocess(train_df["text"])
train_corpus = train_processed.tolist()
train_corpus
# Out:
# ['benedikt rosenau write great authority contradictory property language correct thing define contradictory language exist object definition reality amend thing describe contradictory language exist weve come something plainly false failure description merely failures description im objectivist remember',
#  'stuff delete computer excellent exampleof evolution without creator create computer create sand go silicon go integrated circuit go processor board take thing put together interesting way like plant create oxygen use light photosynthesis much big leap talk something create everything nothing find unfathomable resort believe creator much simpler alternative exist simply incapable understanding beginning -- even beginning thats ok present keep perfectly busy',
#  'deletia deletion somewhere mention something chop hand punishment theft saudi arabia assume wouldnt know assume do people fit requirement muslim find highly likely would please try convince bobby mozumder muslim chop people hand come back youve succeed',
#  'kid shoot make comment jew nazis ww ii say die human hope perhaps kill first blame dead one destroy evidence',
#  '',
#  'deletion cooky charlie claim jesus see discredited extraordinary claim dont match evidence case one gospel cannot even agree jesus see zillion spook story one would hardly consider others even religious context evidence resurrection elaborate argument make look pass post filtering evidence strict mean actual evidence would probably part say nothing claim',
#  'deletion way usually use view say drive car require faith car drive conclusion faith premise argument use thats word game term god use different way usually use different definition thing commonly accept would say way define god exist existence say exist interestingly say existence exist one indubitable statement possible say god existence either waste time existence already use need replace god imply case definition argument far incomplete make fallacy deletion deletion follow arent observation base assumption something exist wouldnt say level definition assumption god meaningful would reject concept anyway',
#  'stiff delete stiff delete speed quantifiable measure result set method result value measure matter reference bullet zero velocity sit table train move 60mph move speed 0mph someone train b 60mph someone stationary next train reference frame make speed relative whats interest every person train see stationary bullet every person bullet move 60mph know train people every time fill see moral problem exactly way',
#  'excess stuff delete know similar incident 3 year ago climatologist ithink profession name iben brown predicted earthquake would hit new madrid fault dec3 school missouri fault line actually cancel school day many people evacuate new madrid town teh wouldnt suprised journalist area resident course teh earthquake never occur know use live southern illinois lican middle school build directly fault line still school laugh poor idiot believe prediction bob youre want excuse convert christianity gonna look elsewhere',
#  'deletion deletion present indeed argument incredulity however see often presented manner usually present form besides cannot see ever offer convincing explanation moreover unreasonable ask explanation phenomenon theism provide convince explanation argument theism favor especially different theism offer different explanation even different adherent purportedly theism give different explanation im experience experience common reason lack evidence theism favor mileage may vary - oh heck ill snide - also fairly easy attack argument make ie strawman sage advice indeed sincerely raymond ingles inglesenginumichedu',
#  'im sorry think discuss heresy assume heresy meant departure orthodoxy case generally accept belief indeed important issue case definition word create great importance since creation issue discuss say give mormon belief disagree mormon belief creation function organization eternally existent substance one ex nihilo creation important point correction interpret bible mean something specific term always crack anti-mormons presume tell mormon believe mormon fact believe people include christ lucifer child god sense create organize whatever also believe offspring god symbolic sense apply spiritually born thus word use convey different meaning language work robert make someone offender word dangerous contrary robert red herring show rely wholly bible cannot seem agree say say one must simply look bible see teach century people sho0wn one really sure say believe one really understand scripture let clarify one time refer mormon belief jesus need save rather mcconkies belief keep try point bruce mcconkie source mormon doctrine keep ignore see contrary robert quote mcconkies word mormon canon question whether canon great importance fact whether indicate general mormon belief would ascertainable interview large number mormon',
#  'still leave door totally open khomeini hussein et rest could still consider true muslim cant judge something god person apply rule well atheistsagnostics dont know belief something god hoopla khomeini real muslim hoopla atheist real human being cheer kent',
#  'object belief say perfect make believer act certain way observe dont contradiction something define contradictorily cannot exist believe exist secondly good explanation believe existence object belief read faq already benedikt benedikt cant recall anyone claim god -makes- anyone act particlar way think youre attempt manufacture contradiction god say require certain behavior compulsion believer sense duty standard conduct exist free ignore misunderstand distort whatever way find convenient response god edicts way use question god existence behavior believer completely separate question god existence nothing contradictory say something define contadictorily cannot exist really ask much would existence depend grammar really say something poorly define insufficient decide anything confusion course point well reason phenomenon belief object belief may lead rat nest unnecessary complexity think know youre imply id like see version well alternative',
#  'good remember every translation extent interpretation point one must really go back original arabic regard verse relevant nature prefer use dr maurice bucailles translation book bible quran science general translation literal maurice bucaille translate portion verse address one travel orbit motion also note celestial body first translation quote translator interpolation -- existent original arabic include bracket youre right verse contain isnt remarkable however dr bucaille surgeon thats hes dr think significant verse contains geocentric idea even though geocentrism rage 17th century go rest quran well 750 verse regard nature think remember reading',
#  'upon arrive home joseph probably take advantage maryhad way speak course word couldnt get around mary highly-religious follower decide hey ill say god impregnate meno one ever know thus see trustworthy honorable soul believe come jesus child bear violence dave explain purpose post cant imagine must thougt meant',
#  'iankmicrosoftcom ian kennedy write along line hebrew 1225-29 reckon see refuse speaks escape refused spake earth much shall escape turn away speaks heaven whose voice shake earth promise say yet shake earth also heaven word yet signify remove thing shake thing make thing cannot shake may remain wherefore receive kingdom cannot move let u grace whereby may serve god acceptably reverence godly fear god consume fire 2nd thessalonian 17-10 troubled rest u lord jesus shall reveal heaven mighty angel flame fire take vengeance know god obey gospel lord jesus christ shall punish everlasting destruction presence lord glory power shall come glorified saint admire believe testimony among believed day kinda give flame whole new meaning reckon - - impression get talk livingston come lord power-wise go something unprepared cant handle -- kinda like overload fuse -- due guilt somehow seem also apply entire physical world know lf suggests god doesnt want send koresh reminder seem purified salvation protect seal one survive -- dont good idea yet shield seal actually involve exactly relate salvation involve marriage bridegroom bride biblical well verse - - personally im totally 100 dependent god christ god want understand good also good god want save dispose thats great either way bear spirit mean part body christ ephesians 2 matter little whats important loving god come nova nuke apocalypse -- care satan might even able pretty convince fake big deal worth fear worry though - great glory god - maybe koresh right maybe isnt interest see new message prophecy tour bible ive take study passages point 3-02 text re- ward test prophecy still fruit bear -- yet clear much much important charity -- definition -- love god hope dear reader youve take expression faith statement mere fact seem many folk get real upset reminder -',
#  'well fair amount evidence float around indicate oto around since least late 1800s long crowley ever heard long amorc around yes know claim exist organization clear prehistory doubt organizational paperwork non-profit carbon-dated 20000 bc alizard',
#  'ref encyclopedia religion mircea eliade magi sneak preview later still eschatology apocalyptics fertile meeting ground iranian judeo-christian religion see famous oracle hystaspes work whose iranian root undeniable likely date begin christian era probably second century ce widengren 1968 zoroastrian doctrine savior future saoshyant basis story come magi bethlehem gospel matthew 21-12 old persian word magu render greek magos uncertain etymology may originally mean member tribe avestan compound mogu-tbish hostile member tribe meaning would resticted among medes member priestly tribe perhaps priest benveniste 1938 boyce 1982 term probably median origin give herodotus mention magoi one six tribe medes variety reason consider magi member priestly tribe median origin western iran among persian responsible liturgical function well maintain knowledge holy occult likely supremacy median priesthood western iran become established time median monarchy dominate persian end eighth century first half sixth century bce revolt cyrus great 550 bce persian indebted medes political civil institution well even hypothesis advance concern existence magi persian origin achaemenid period boyce 1982 must still maintain median origin demonstrate eposide revolt gaumata magian mention darius 522-486 bce inscription bisutun iran well greek source indeed herodotus insists idea usurpatory power medes persian conspiracy magi fact magi may member tribe handed sacerdotal art hereditary fashion naturally exclude possibility undertook secular prefessions seem attested elamite tablet persepolis thesis put forth giuseppe messina deny magi member ethnic group suggest simply member priesthood - priesthood purely zoroastrian origin thesis untenable hand hypothesis name related avestan term magavan derive gathic maga vedic magha gift without foundation mole 1963 meaning maga probably find conformity pahlavi tradition within context concept purity separation mixture two opposed principle spirit matter maga erroneously interpret chorus root mangh say mean sing magic song nyberg 1966 render simply expression like unio mystica seem ecstatic condition open mind spiritual vision case though may relation old persian term magu avestan term magavan maga must maintain clear distinction magi avestan priesthood avesta ignore median old persian term despite recent hypothesis propose hw bailey old persian inscription ignore avestan term priest athravan vedic athravan even perhaps present achaeminid set elamite tablet persepolis gershevitch 1964 term magu present zoroastrianism throughout history pahlavi term mogh-mard mobad represent continuation latter particular derives older form magupati head magi sasanid period third seventh century ce saw formation hierarchically organize church title mobadan mobad high priest high priest come used designate summit ecclesiastical hierarchy magi practice consanguineous marriage khvaetvadatha av pahl khwedodah also perform characteristic funeral rite exposure corpse animal vulture remove flesh thereby cleanse corpse suppose decompose l contaminate demon putrefaction practice later become typical entire zoroastrian community lead rise complex funeral ritual iran among parsi india stone tower know dakhmas build especially rite time herodotus practice exposure corpse vogue among magi persian generally sprinkle corpse wax bury practice widespread however among people central asia magi technician expert worship impossible offer sacrifice without presence magus performance ritual sacrifice magus sing theogony magi possibly custodians tradition sacred poetry know nothing relationship tradition various part avesta call upon interpret dream divine future magi also know practice kill harmful ahrimanical animal khrafstra snakes ant dress median style wear pant tunic coat sleeve wore characteristic head cover felt gr tiara strip side could use cover nose mouth ritual avoid contaminate consecrate object breath boyce 1982 color cap conformity tradition pro ...
#  'emarshhernes-sunengsuncom eric huh please explain problem base morality something could wrong gosh there heck lot stuff believe could wrong come source could wrong base belief atheism knowledge reason couldnt wrong mac -- michael cobb wont raise tax middle university illinois class pay program champaign-urbana -bill clinton 3rd debate cobbalexialisuiucedu',
#  'entirely premise conclusion second scientist part exlude possibility problem necessity scientist empircists theologian scientist long clearly deep fundamental misunderstanding science absolutely utterly false except amhs lucy australopithecus afarensis ca 3 325 mya 40 complete 80 take consideration bilateral symmetry lucy walk upright bipedally like human two share remarkably similar dental pattern cranial morphology unlike human modern ape hundred specimen specie partially reconstruct exist bill touch feel hold forget hominid earth universe cultural record look test ancient indeed reconstruction god trick u wont go away bill fundamentalist say billion dont say beware people say truth bill reconsider time think point bill point god power scientist generally agree thats far cry say god please attempt understand post info reply - several day ago hope somehow post appear server today',
#  'necessarily especially rapist know instance intentionally stick finger load mousetrap get snap whose fault',
#  'craig- thought derive greek acronym greek isnt much go something like jesus christ god iesus christos theos ichthos greek fish eg ichthysaurus apology dreadful greek perhaps someone correct way sig mean',
#  'context must miss say promise god keep get subject could please explain wrong ok acknowledgement public hypocrisy neither accord jim way criticize one person take quote context without hypocrite post response every person trm take quote context either ask assert misaimed telepathy work 1 stephen say take quote context 2 note stephen reply trm article call take quote context 3 lack evidence x constitute evidence lack x common creationist error 4 fact stephen reply justify conclusion stephen condone take quote context excellent condition could conclusion make direct assertion part instance assume position eat shit merely say position might conclusion make observe 7 assumed logical sentence begin could please explain nonsequitur intend follow sentence precede well jim call argument disagree explain argument sound admit assumption 7 may bite hasty agree say yup',
#  'agree reckon television increase fundamentalism think increase pre-marital sex others think psychologist take criminal justice system let violent criminal con let street others think increase designer drug others think communist plot basically social interaction change factor society far complicate u control hold panic handle hope head soft land one thing sure depression destruction nuclear family due solely sex marriage jeff',
#  'headpiece chortcrlnmsuedu source ap newswire vatican home genetic misfit michael gillow noted geneticist reveal unusual data work undercover vatican past 18 year popehattm actually advanced bone spur reveals gillow groundshaking report gillow secretly study innermost working vatican since return vietnam wheel chair first approach scientific community theory late 1950s whole hat thing cover vatican didnt want catholic communitytm realize leader heft nearly 8 kilogram extraneous bone tissue top skull note gillow report whole laboratory vatican experiment tissue transplant bone marrow experiment start genetic fluke mid 1400s scientifically engineer bred whole bone transplant idea start mid sixty inspire doctor timothy leary transplant deer bone cell small white rat gillow quick point assassination attempt pope john paul ii disappearance dr leary public eye becomes time replace pope say gillow old pope replacement pope lock padded chamber butt head much like male yak fight dominance herd victor emerges earn privilege inseminate choir boy p',
#  'thanks whoever post wonderful parody people post without read faq laugh good 5 minute part faq werent mention think might one two please dont tell wasnt joke im ready hear yet',
#  'actually important thing glean mess 1 start get desperate answer question whats mr natural pinkboys buy darn near anything mean 2 there still plenty make false jesus business enterprising subgenii remember 3 youve separate pink green dont blow automatic weapon mexico put swiss bank account smile lot flunky hand flower airports con shrug long 4 never never never start believe bulldada david koresh handt start swallow apocalypso crap hed work crossword puzzle bahamas today instead contribute mulch layer waco 5 start shoot cop theyre likely shoot back em well shot short - pt barnum right - stupidity self-correcting thus endeth lesson',
#  'attempt define objective morality long keep almost freedom mostly valuable thing people think youre really say real big lot people agree freedom subjectively valuable thats good quite nice start point moral system universal thus objective isnt sahara',
#  'ken arromdee writes yes tell think question answer question bds didnt know immediately deal fed uniform apparel insignia must figure pretty short order keep fighting seem awfully ready attack without warn',
#  'god eternal b jesus god c therefore jesus eternal c b work logically mathematically god set thing eternal jesus subset god therefore jesus belongs set thing eternal everything isnt always logical mercedes car girl mercedes therefore girl car',
#  'jehovah witness believe christian require observe sabbath whether saturday sunday sabbath part covenent god israelites require christian',
#  'seriously though griffen didnt save live child destroy life man superficial level he scum almost agree griffen scum scum guilt freedom choose anything griffen god make scum make griffen make precious person person choose wrong go dr gunn examine closely griffen would prefer child bear -- yet birth griffen assistance offer griffen intend support educate raise useful citizen intent whatsoever help child birth here real problem americans become insensitive need others completely wrap cannot see straight think clearly enough make even slight obvious moral decision base reality man abandon woman care child consider respectable decent man anyone man flee responsibility behave like lazy coward turn away responsibility wife child however woman decide kill unborn child release burden think way man abandon woman suffers child free grow live happy normal life woman abandon child dice killed saline vacuum man choice man sometimes suffers badly wish could trade place child th root whole problem selfishness--the arrogance say feeling desire supreme well worth dung come substance hell make reason love god throw selfish people devil demon eternity let one u unrepentant heaven well ruin first chance get dont really know answer question ive got real good guess probably right wouldnt call benevolent either move right direction dont see responsibility kill get sight medium back u completely real responsibility sell responsibility sell marketplace enough make u feel responsible without show anything might show u true irresponsibility want feel like good people want nothing good people give freedom say im good rest world burn rape kill child throw parent place poor old folk rot theyre dead ill hate brother sister wish ill cheat wife husband screw government screw dont talk give church church people bunch money grub hypocrite im good person least admit least love know great love world--not man lay life brotherthat sound christian root substance hell make weve become self indulgant backslidden society longer responsible child parent family government god root behind justification every evil every corruption government every slanderous remark every lie every murder society cannot continue live like long destroy itsself soon perhaps end big bless world hope see people see much evil try turn situation around -- ----------------------------------------------------------------------- deplore horrible crime child murder want prevention merely punishment must reach root evil practice whose inmost souls revolt dreadful deed mater motive love ease desire save suffer unborn innocent woman awfully guilty commits deed oh thrice guilty drove desperation impel crime',
#  '930420 thou wilt shall whole law word sin restriction sorry san jose base rosicrucian order call amorc dont remember time stand orc ordo rosae crucis word latin order rise cross response yes true entire title ancient mystical order rosae crucis locate 1342 naglee avenue san jose california 95191-0001 usa consider different largely unrelated number source ive see documentation link figure h spencer lewis lewis apparently involved reuss oho ordo templi orientis many year apparently also true lewis charter form oto body create amorc subsidiary interest question kent otherwise headquarters san jose pretty decent metaphysical bookstore interested book son love run around egyptian museum response indeed diagonally across street another metaphysical book store call ram metaphysical wherein ive purchase wonderful work crowley others ram metaphysical book 1749 park ave san jose ca 408 294-2651 invoke star love law love',
#  'problem technology cause type make thing even bad must remind inquisition operation rescue ku klux klan posse comitatus 700 club david duke salem witch trial crusade gay bashings etc plus virtually every single war regardless level technology theistic organization cheer carnage chaplain etc claim god favor whole ordeal dont forget pray troop really tedious every bad thing thats ever happen malefactor influence religion - anyone -really- believe ive see often must pretty general opinion aa want believe atheist really dishonest please stick fact accomplish interpret correctly',
#  'stuff delete five school law best knowledge support death sentence apostasy accompany open persistent aggravate hostility islam otherwise agree legal support punishment disbelief quran make clear belief matter conscience public private disavowal islam conversion another faith punishable jurist go trend insist apostasy punishable even death - historically exception curse insult prophet fall category shatim',
#  'ahhh go back altautotheism belong',
#  'make 20 see poll recently religious adultery newsgroup altatheism place',
#  'nice cop bill im sure youre right idea refer would mind explain copped',
#  'quotation mark enclose law must rule even instinctive one unwritten one etc surely sort random chance would lead chimp society chaos',
#  'happens subjective example people u would happen agree continue move price point people would accept probably would accept high enough number endpoint subjective scale give home objective viewpoint',
#  'actually simple person p commit crime c country x p within border x time c commit doesnt matter physical manifestation c outside x instance hack nasas ames research lab delete file commit crime united kingdom u authority wish prosecute u law rather uk law automatic right net authority u try put pressure site holland holland anti-cracking legislation view hacker u system administrator similarly company call red hot television broadcast pornographic material receive britain broadcasting britain would commit crime broadcast denmark british government powerless anything spite apparent law-breaking course im lawyer could wrong confusingly could right country others',
#  'id say problem organization religious idea simple speech basis crime',
#  'say bible christian suppose persecute jew isnt love enemy instead may say christian action speak differently believe everyone tell dont come believe god investigation conclusion ultimately choice salvation however grant grace god christian model oneself jesus christ imply name christian say believe head feel heart say belief white supremists neo-nazis brand christian hate see love god cannot see belief entail believe christ sin forgive name give christian free licence sin repent sin ask forgiveness sin try christian lump racist accuse pre-judging btw chinese racial background know part visible minority country dont think would favourably look upon white supremist christian call anyone say believe dont practice preach belief false concur nazi racists general one come immediate attention believe people may use bible mask racial intolerance bigotry hide behind christianity tell jesus would nothing arguement point im try make call christian may christian ask draw conclusion say model example jesus christ christian repent sin accept jesus christ personal lord saviour christian criterion christian may god',
#  'many injustice middle age truely sad would hate see day church put people death torchured practice homosexuality crime church call take government world may homosexuals treat cruelly today mean teach christian practice homosexual immorality think also teach christian practice divination channel witch middle age persecute accuse judge look heart see love write teach christian practice homosexual immorality pretend divine knowledge look heart cant say love homosexual should- cant say love neighbor either dont know many homosexual jesus love homosexual love everyone else love conditional know yes show love homosexual love encourage brother church stumble continue sin damage dangerous thing slander could easily say nambla able implement legislation make child molest easy tear society morality due people accept homosexuality normal embrace believe homosexual sex immoral mean endorse use violence problem hatred church also problem call unsanctified mercy many conservative church see moral breakdown country storm horizon gotten militant flesh truely sad yet others church embrace immorality society point carnality conservative church justify action certainly use bullwhip drive people jesus shouldnt water gospel draw people jesus didnt go way show might consider positive aspect draw people tell one man sell tell another say good bye family word hard time present people cost tower allow begin construction many people already innoculated gospel link hudson',
#  'dan johnson- dont know take hand anyway bravo god 0 beautiful simply beautiful',
#  'course point cant simply divide world atheists non-atheists basis god-belief care belief supernatural deity nothing say behaviour belief supernatural criterion start talk behaviour someone suscept- ibility lead bad people bad thing - assume - worried area care whether someone sceptical critical autonomous one hand gullible excitable easily lead would say tendency worship tyrant ideology indicate person easily lead whether worship belief supernatural hero rather earthly one seem beside point',
#  'im greatly need jurgen moltmanns book god creation ecological doctrine creation copy youre willing part id love hear soon may call 312-702- 8367 e-mail thanks',
#  'horror story fbi ruin guys life hell omit real story work fiction source newspaper get hypothetical',
#  'painless isnt cruel occur frequently since dawn time hardly unusual innocent die due many cause single accidental false execution one take issue',
#  'dr englands story deleted nice read first time isnt much matter interpretation bible texts set mormonism apart orthodoxy matter fabrication 20 year ago national lampoon comic strip draw neal adam call son god comic parody jesus bible comic group thirteen jewish kid brooklyn one say magic word turn son god go myopic curly head yarmulke wear boy replica stylizied portrait jesus --- long flow brown hair gentile feature someone profess faith natlamp jesus claim christian believe natlamp jesus would say fallacious since jesus fabrication really exist exact thing lds claim christian profess faith jesus jesus profess faith much fabrication natlamp jesus',
#  '',
#  'worry mason demonize harrassed almost every major xian church century still stand wil withstand miserable southern boobtists sure may even pick little support people start listen boobtists realize subtract obvious lie claim satanism mason sound pretty good comparison one thing know sizable proportion southern babtists mason mason already fire back magazine boobtist witch-hunt since consrervatives already divisive element war boobtist moderate liberal may start masonboobtist brother hasten downfall southern boobtists realize church cant stand run handful clown look holy civil war purity test drop em leadership position take far concerned loud ruder outrageous anti-masonic crusade old goat mount good pop pocorn get center row seat circus begin oh look come clown pope charles slack',
#  'anne frank exhibit make small little world take afternoon go see bob beauchaine bobbeviceicotekcom say queen could stay blew bronx away sank manhattan sea',
#  'know shouldnt get involve - bit deleted righto dan try one cornflakes book say muhammad either liar crazy modern day mad mahdi actually say reason wouldnt liar follow would die lie wouldnt people able tell liar people gather around keep many gathered hear see son-in-law make sun stand still call fool believe make sun stand still niether lunatic would entire nation drawn someone crazy doubtful fact rediculous example anyone drawn mad mahdi obviously fool logical people see right away therefore since wasnt liar lunatic must real thing --',
#  'actually atheism base ignorance ignorance existence god dont fall atheist dont believe pride mistake bob beauchaine bobbeviceicotekcom say queen could stay blew bronx away sank manhattan sea',
#  'critus',
#  'there another point make inside burn house know want stay alive good run build one case fbi agent drag woman burn house run back saw force arrive good indication fanatical mind follower -- include child burn instead save innocent victim instance cheer kent',
#  'hope didnt award custody rich purposely use handle order avoid - ie happen religion course aberration like scientific creationism use best part indicate science currently time domains mostly ignore also attempt brief doubt confuse matter aside science write nobody seem argue seem answer would vary individual individual im try evasive societal perspective religion work hand sometimes abuse misused many suffer know net result seem positive anthropological perspective human affair might call neo-fruedian insofar think mass cant get along without religion generally incapable dont myriad reason main one seem promise immortality seductive immortality therefore seem theologian well equip others mention dispense answer suggest hold regardless truth answer simply people believe end spiritual belief real scientific fact explanation caution take context fact dont think close least individual isnt group theoretical physicist argue matter create nothing big bang singularity approach might presuppose absence except seem could argue something responsible nothing maybe something doesnt supernatural maybe mechanistic thats tough one people today grasp case theory without empirical data explanation question require data word agree theorize within scientific parameter scientific explain answer close scientist sense science realm currently inadequate data necessary improvement seem long way ever pretty convolute hope ive make sense agree generally prefer put way - question open inquiry enlightenment reason reponsible question theological answer part science thus born naturalist curiosity eventually cart away largely leave behind ignorant selfish intolerant arrogant course still claim authority four domain much oblige funny fact tend muddle thing isnt well sure plenty scientific creationist rebuttal somewhere even create nothing record amh anatomically modern human best regard -',
#  'define perfect take foot mouth wonder already catholic christian fact contradiction unresolvable one reason atheist believe believe similar sentence long time show power religion anything claim follow definition evil ordinarily use let evil happen allow evil take place place even cause evil another evil omniscient attribute god know creature even omnipotent create choice leave known course event fix even omniscient extend argument james tims omnipotent free say something choice scenario give therefore define free imagine follow good being cannot harm easily implement make everyone appreciate object good deed dont make long feel absence good evil whose case argue conceivable omnipotent would omnipotent want logically consistent well give pet idea omnipotent first deletion bible describes omniscient omnipotent god destroy credibility bible nothing less',
#  'respond jims article today see neglect respond one wouldnt want think hypocrite respond every stupid article trm dictionary definition disagree agree delete oh im weary try wade jims repertoire red herring smoke screen let see get run four article post jim today discord filter markov chain program steve lamont kind enough send take white geese hold accomplice hold decision upon door black white goose waddle past eye door hit confidence interval individual hold responsible individual may hold getaway car may hold uncountably large number driver something agree black goose waddle past person imprison white goose waddle past confidence interval population geese axed fine white goose waddle past door run jims article discord make coherent le coherent discord turn jims article angst-ridden poem making choice world fill uncertainty yet hold responsible choice make geese symbolize inner frustration ambiguity desire everything black white shade gray getaway car tell u try renounce existential nature get away responsibility action rather take role passive accomplice driver getaway car juxtaposition man machine car driver reveal subtext internal conflict determinism moral responsibility read much collaboration jim random number generator',
#  'care fellow write anyway mean come psuvm could possibly importance disperse smiley longer offend',
#  'ill defer great firsthand knowledge matter',
#  'know occur today whole christian thing blame solely mary shes marry joseph get knock think ol joe find shes get around mary come ridiculous story god make pregnant actually cant ridiculous consider number people believe anyway never tell anyone truth even tell poor little jesus he hot shit son god everyone else tell since theyve buy marys story mary actually turn adultress liar cause mankinds great folly recently-minted two cent chris',
#  'question regard islamic view towards homosexuality come discussion group participate id like ask question islamic view towards homosexuality',
#  'didnt hear address change reach follow address dkoreshbranchdavidiancompoundwacotxus think last see post altmessianic jim',
#  'warn job convert job holy spirit frankly make lousy one testify conversion god loop decide follow jesus indeed would estatic glory god',
#  'mr connors assertion complex later paleontology simply incorrect many lineage know whole structure lose -- example snake lose leg cave fish lose eye specie almost completely lost male kiwis descend bird functional wing joel statement make illustrative inescapably anthrpomorphic quality desciption evolutionary process way evolution describe explained term teleological whole point even reason believe understand evolution biologists instance tend personify nature cant help wonder limit language nature nature',
#  'rick anderson reply letter ra article ra briefly something mention pass refer differ interpretation create say many christian may agree really irrelevant base faith many people think one way another bottom line truth regardless popularity opinion may irrelevant personal belief say bias relevant many others youre right bottom line truth independant anyone else since proclaim truth self-proclaimed appointee may ask authority say bible --does bible say someone else interpret whether scripture doctrine conforms particular like disapproval excuse moi line truth havent move one bit persuade beliefs erroneous preacher truth net struck self-righteous member wreck crew positive message latter-day saint btw entire discussion remind lot thing say jesus pharisee ye hypocrite ye preach lip hearts far remove also find rather strange try persuade create eternally existent equivalent say grant mormon belief cant grant conclusion expect point address order reply issue address answer point raise jump conclusion grant sophistry look who talk jump conclusion wouldnt right address conviction regardless whether come biblical scripture support point view reject interpretation without consideration whatsoever bible state lucifer create bible state jesus creator contradiction lds belief jesus lucifer beautiful example disinformation deliberate misrepresentation lds doctrine former kgb would love employ jesus lucifer silly know mormon belief child god literally nothing symbolic however contradicts bible say bible teach everyone child god correction may contradict would think bible say bible indeed teach child god sense belong follow god footstep satan follower rebel god child followersredeemed god doesnt mean create god choose separate chose follow god plan salvation field world good seed child kingdom tare child wicked one matthew 1338 kingdom remain valiant testimony jesus show work repentance etc child wicked one rebel god lamb issue satans spirit-origin followed address verse copy bible purposefully obscure subject swamp right non- related scripture lots nice scripture delete robert w copyright though ra tell life eternal might know ra thee true god jesus christ thou hast send ra john 173 life eternal know true god yet ra doctrine lds mention portray vastly ra different jesus jesus cannot reconcile jesus ra bible far remove proclaim correction jesus indeed different jesus reconcile jesus bible --not interpretation concur honestly couldnt care less ra one true deny true accord ra bible eternal life dependent know true god ra construct imagination single post ive see construct imagination pro-lds mail combine read far news group first get lds-facts straight dare preach u true god interpret accord like dislike whose image cannot reconcile know guess grandiose self-image allow faith believe divinity jesus christ different way fashion really matter mission progress lds church go boldly nobly mob opponent stop work progress visit every continent sweep every clime sound every ear really red herring doesnt address issue raise rather seeks obfuscate fact group try read something bible doesnt change bible teach sigh bible teach bible teach accord robert weiss co respect former reject latter without remotest feeling reject jesus contrary way respect interpretation bible even grant christian follow image much christian follow image heart reply instead hop-scotched issue bruce mcconkie whether view official doctrine dont think matter mcconkies view canon issue mcconkies write indicative mormon belief subject real issue indication rick may certainly issue course love use anything either mis- represent ridicule lds church issue official doctrine obviously important mcconkies view controversial eg seven deadly heresy make heretic - best erroneous bad black receive priesthood dispensation respect someone make valuable contribution church personally rely personal interpretation book mormon doctrine oftentimes refer mcconkies bible mormon circle mormon doctrine rat ...
#  'excite thread finally mitra sanskrit friend start avatar lord visnu mention first vedas later seem rise chief prominence worship persian associate sun sun lord contract honor obedience therefore naturally worship soldier order sun slay bull heaven reluct- antly agree obligationthe blood bull spill grow earth lifethen mitra sun sit eat worship lord mitra end persia ascension zoroastrian hundred year later rediscover throw official roman pantheon tm semi-tricky reason forget reference end abruptly stricken apparently worship sort vehicle advancement bureaucracy like membership communist party soviet bloc sociology religion ancient time fascinate oh b-day 25 dec ahem sure mystery cult really last boot roman imperial god roster contain mostly soldier 7 level initiation worship underground cavern pew bull horn temple scar away impale evil spirit im sure mithraic significance dont know ritual meal cannibalistic nature christian mass eat deity go way back old kingdom egypt someone mention bullfighting mithraist sacrifice bull forget likely religious source might shower bull blood enjoy worshipper cybele day blood cybele worship extend throughout even france bigtime',
#  'actually one condemnation lesbian act bible roman 126 think plenty dont read bible pray matter',
#  'jim brown write delete delete unfortunately simple kjv prefer majority fundamentalist least second part argument fail well since statement use version kjv delete delete would find statement useful since appeal authority opposition claim authority well second tact local creationists use reply scholar atheists cannot believe also use phrase describe theologian dont agree delete delete',
#  'thing ye learn receive heard see god peace shall',
#  'well hanging quick imagine painless hanging fire squad allow today thing consider cruel surely medical execution painless would either',
#  'ps9212 righteous shall flourish like palm tree',
#  'frankd012s658uucp frank odwyer write ill agree generally hold good thing question whether come close objective value especially consider one time another view undesirable doubt could even come anything could say universally good bad refer truth use term hypothetically realize full well may even thing true enough cannot say anything personal moral one thing notably lack extremist sense personal accountability - justification socially unacceptable behaviour invariably high authority aka absolute moral truth objective truth say one cannot know objective truth interesting notion - certainly one one moral belief compromise good compromise absolute truth something people successfully suppose one could hold compromise absolute moral happen someone else insist compromise compromise compromise almost invariably consider relative value one thing another moral consequence people consider aspect justify desired belief justify commitement peace might argue let people live long healthy peaceful life much may well true incomplete ignore benefit war - kill agressive member society trim population stimulate production equation always complex present characterize relative moral merely follow one conscience desire unduly simplify',
#  'good point think average people take christianity much fear escapism quite simply way improve social life get involve american culture kid immigrant example since overwhelm major religion western world form simply choice people take bore want something new life somethong new ordinary seem little weak long doesnt hurt anybody good quote agree let make sure alter scond one include something like let long prevent others find peace something like course suppose someone really peace would need inflict evangelism well sure thing live live popularity seem come go remember first enter high school atheist always 7 friend time 5 7 convert always christianity also immigrants taiwan son immigrant hence earlier gross generalization christianity seem lot popular people ever since ive noticing maybe perception chagning know one perfectly willing live let live long set abstract rightsagreements treat desire hurt notion well-put argument usenet never good argumentation really seem apply christian even atheists- must simply step person take naturally almost instinctively best regard adam john cooper verily often laughed weakling think good simply acoopermacalstredu claw',
#  'lev 1711 life flesh blood give upon altar make atonement soul blood make atonement soul old testament big eye eye business make sense leviticus would support physical injury repay moral wrongdoing know sanctification ive taught sunday school catechism class theology class even still cant accept maybe im still understand maybe im understand well bottom heart know punishment innocent man wrong ive try repeatedly course several year accept cant mean cant accept premise god would allow perfectly good explain death jesus good thing would glad hear might even convert warn however ive heard common argument dont convince',
# ...
#  'claim absolute morality objective one',
#  'know obviously koresh nut case typical inability governmentmedia get story straight quite disturb tuesday night nbc news report fbi know place burn saw black smoke billow build next day fbi agent insist saw davidians set fire fbi also adamantly deny possible battery compound wallks could accidentally set blaze also say hadnt able much investigating site still hot know didnt accidentally set fire sound like fbi burn place ground destroy evidence',
#  'well islamic viewpoint homosexuality norm society cannot really say much islamic viewpoint homosexuality something do much research',
#  'red wwhite black color imperial german war-flag --',
#  'one favorite fallacious point atheism ie belief cant deny anything cant prove doesnt exist easily nail show infinite number being conceivable observed exist mean would believe accord poster must believe object beings havent prove exist stop god could huge number being identical ronald reagan except trivial difference say one miss finger one blond hair live planet cant see reason one atheists bring none christian vested interest unknown being exception god shoot foot big difference stalin didnt say stand particular moral position ie murder terrorism etc opposite like religious movement least honest killer support stalin attack viewpoint say atheism support murder violence one man tyrant atheist bad logic look russian help stalin werent atheist - dont contradict point besides point assumes atheism relevant murdering people common assumption atheist cant value life much theist didnt support ah heres another point didnt get faq atheist doesnt hold positive view god doesnt exist heshe may non-existence positive belief here example strong atheism - believe god exist positive belief weak atheism - dont believe god negative belief one never think idea god whole life technically atheist kind call unreasonable let look way set suppose give person huge set idea represent capital letter people either believe idea exist real object santa es person believe santa still idea santa notice even es another idea mean lots case christian aeayesbebno gegyes g god atheist strong aea gegno atheist weak ae ie g set agnostic ag eg indeterminate e nietzsche say man would rather nonexistence darwinist way put humanity always prefers yes maybe indecision useful survival trait evolution drill u take position even false one',
#  'archive-name atheismresources alt-atheism-archive-name resource last-modified 11 december 1992 version 10 atheist resource address atheist organization usa freedom religion foundation darwin fish bumper sticker assort atheist paraphernalia available freedom religion foundation u write ffrf po box 750 madison wi 53701 telephone 608 256-8900 evolution design evolution design sell darwin fish fish symbol like one christian stick car foot word darwin write inside deluxe mould 3d plastic fish 495 postpaid u write evolution design 7119 laurel canyon 4 north hollywood ca 91605 people san francisco bay area get darwin fish lynn gold -- try mailing net people go lynn directly price 495 per fish american atheist press aap publish various atheist book -- critique bible list biblical contradiction one book bible handbook wp ball gw foote american atheist press 372 pp isbn 0-910309-26-4 2nd edition 1986 bible contradiction absurdity atrocity immorality contain ball foote bible contradicts aap base king james version bible write american atheist press po box 140195 austin tx 78714-0195 7215 cameron road austin tx 78752-2973 telephone 512 458-1244 fax 512 467-9525 prometheus book sell book include haughts holy horror see write 700 east amherst street buffalo new york 14215 telephone 716 837-2475 alternate address may newer old prometheus book 59 glenn drive buffalo ny 14228-2197 african-american humanism organization promote black secular humanism uncover history black freethought publish quarterly newsletter aah examiner write norm r allen jr african american humanism po box 664 buffalo ny 14226 united kingdom rationalist press association national secular society 88 islington high street 702 holloway road london n1 8ew london n19 3nl 071 226 7251 071 272 1266 british humanist association south place ethical society 14 lamb conduit passage conway hall london wc1r 4rh red lion square 071 430 0908 london wc1r 4rl fax 071 430 1271 071 831 7723 national secular society publish freethinker monthly magazine found 1881 germany ibka ev internationaler bund der konfessionslosen und atheisten postfach 880 d-1000 berlin 41 germany ibka publish journal miz materialien und informationen zur zeit politisches journal der konfessionslosesn und atheisten hrsg ibka ev miz-vertrieb postfach 880 d-1000 berlin 41 germany atheist book write ibdk internationaler bucherdienst der konfessionslosen postfach 3005 d-3000 hannover 1 germany telephone 0511211216 book -- fiction thomas disch santa claus compromise short story ultimate proof santa exist character event fictitious similarity live dead god -- uh well walter miller jr canticle leibowitz one gem post atomic doomsday novel monk spend life copy blueprint saint leibowitz fill sheet paper ink leave white line letter edgar pangborn davy post atomic doomsday novel set clerical state church example forbids anyone produce describe use substance contain atom philip k dick philip k dick dick write many philosophical thought-provoking short story novel story bizarre time approachable write mainly sf write people truth religion rather technology although often believe meet sort god remain sceptical amongst novel follow relevance galactic pot-healer fallible alien deity summons group earth craftsman woman remote planet raise giant cathedral beneath ocean deity begin demand faith earthers pot-healer joe fernwright unable comply polish ironic amusing novel maze death noteworthy description technology-based religion vali schizophrenic hero search hidden mystery gnostic christianity reality fire brain pink laser beam unknown possibly divine origin accompany dogmatic dismissively atheist friend assort odd character divine invasion god invade earth make young woman pregnant return another star system unfortunately terminally ill must assist dead man whose brain wire 24-hour easy listen music margaret atwood handmaid tale story base premise u congress mysteriously assassinate fundamentalist quickly take charge nation set right ...
#  'would like add support misctaoism discussion group applaud enthusiam show person post thyagicupportalcom read altmagick differ himher believe least minimal parameter agree upon dont limit something discussion degenerate big amorphous glob question thyagi propose seem question properly fall category general metaphysics would prefer misctaoism deal closely topic work closely associate least semi-orthodox taoism establish classic work definitely include work like mantak chias argue think neo-taoism exclude get group mean humpty-dumpty taoism taoism mean whatever poster say mean alttaoism could also refuge debate taoism really mean speculation sexual alchemy etc eg thyagi kent gloomily predict quote thyagis article think discussion nature completely place whats happen term taoism become completely pollute trivialize like word magic alchemy zen etc writer appropriate word mean whatever want see spate new age book entitle tao everything else respect exception like book jou tsung-hwa commentsideas look forward see balance say let misctaoism rip let chip fall may get fill college freshman ask tao sex failure people post group --',
#  'clarify earlier quote god law originally write israelites jesus change fact make law applicable people jew gentile could part kingdom heaven save grace god never say law make obsolete jesus reference here earlier quote malcolm lee mleepostroyalroadsca write reference leviticus 219 deuteronomy 2220-25 law write israelites god choose people god expressly set apart rest world israelites direct witness god existence disobey god know god real would outright denial god therefore immediately punishable remember law write different time apply god choose people jesus change living age grace sin longer immediately punishable death repentance salvation lord jesus christ choose people salvation available everyone jew gentile alike two conflict statement say one clarification breach logic dont mind people shift position issue irritates say premise change make deuteronomy 2220-25 wrong jesus change anything clarified law quote make follow verse jesus take several portion law expound upon law give clear meaning god intend sure however doesnt address notion stone non-virgin bride need clarification go deny deuteronomy 2220-25 patently clear intent think agree today world lot modern-day pharisee know bible end end believe good head knowledge nothing heart ill agree lot modern day pharisee know bible end end dont believe depend use knowledge scary argue position desire back select part bible pharisee include david koresh adolph hitler qualify say dont know actually believe preaching end certainly make mean look frighten however scary dont know much bible believe every word fact probably scarier since far people ive see addition easy manipulate aforementioned pharisee since dont know enough debate people christianity set rule lifestyle change one perspective personal conduct demand obedience god demand obedience book god come personally tell behave would say would gods however preacher pastor evangelist tell obey book write people dead close two millenia even longer ot even follow everything heart could scarcely honest say im god people live many others cannot choice respect god respect well god respect much come talk bible eternal damnation non-believers see little respect eminating god bible see selfish spiteful god god thanks malcolm lee rob lanphier lanphi872snakecsuidahoedu lanph872uidahoedu curious earlier post',
#  'sandviknewtonapplecom kent sandvik write ks see youre want malcolms response allow one last inter- jection please distinguish among religious jew youve except messianic obvious reason specifically say religious jew trace lineage back abraham blood orthodoxy rather faith wont agree orthodox jew aa understand direction issue remain unproven suspect consider atheist agnostic often look reason atheist reasonable conclude agree agnostic poll seem order know im sure atheist count orthodox wonder many would follow moses abraham david accept god word particular covenant one adhere important god promisimg reckon many depends ongoing dialogue consideration might understand think premature assert wont agree',
#  'cool quote well watch theist jump - nanci',
#  'heard ask fbi provide word processor anyone know koresh request wordperfect50 wp50 write owned mormon theological implication request refuse wp50 profound',
#  'assume talk appeal process etc well noted people imprisoned life also tend appeal though quite much final hour anyway economics good reason either favor oppose punishment',
#  'rest delete anybody aph help find night brown shirt',
#  'paradise salvation thing salvation well refer john 142',
#  'talk majority people support anyway think revenge fairness people favor punishment murderer go punished people think get deserves people wouldnt think would fair murderer live victim die perhaps think petty pathetic view minority require compassion forgiveness sympathy someone wrong take great length make sure advantage remove similar situation force upon someone kill another apply golden rule kill person turn entire moral system base concept state human life sacred somehow never violate would sound like sort religious view criminal commit murder desire irrelevant still answer question concern death penalty due possibility execution innocent isnt concern share imprisonment shouldnt logic administer minimum punishment possible avoid violate liberty happiness innocent person',
#  'deletion first infinity mathematical concept create human explain certain thing certain way dont know actually applies reality dont know anything world infinite dont know universe actually continuous continuum another mathematical concept base infinity use explain thing certain way pretty good idea infinity man-made concept like many man-made concept evolve time ancient greek different understand precicely dont even know infinity applies reality',
#  'walter- try several time past communicate susan ignore dont honestly believe letter mean rather think thoughtful compassionate see see call naive give group lord advise unwelcome city brush dust foot go anyone care topic write direct well may god bless well',
#  'objective system talk goal brand morality talk',
#  'response whittenfwvasaiccom david whitten respond course feast seder account clear point difference connection bread wine body blood god old association tammuzosirismithras line really related judaism case didnt really intend argue point saw possible association point havent foggy notion really happen',
#  'could start poster annoy u like bobby bill wish command bill shit-stirrer connor bobby circular mozumder im sure new nom dnet exactly appropriate come close consider wade make one insightful dead-on-the-money repsonses agree somethings get stir would like believe characterization respond would kinder though insist also surprise find offended anyone case unavoidable say anything fairness important check contribution havent generous patient veritable paragon gentility oh btw dont mind pair bobby admire tenacity many would well hostile environment - think -im- offensive read post love kiss bill ps',
#  'system refer moral system havnt show reason chimp must moral system except would like redefine everything --- whatever promise make broken',
#  'see youre run ultrix - - - steve',
#  'always think pope bear know little say bear shit wood pope catholic',
#  'look historical evidence perfect utopian islamic state didnt survive agree people people even might start islamic revolution create perfect state take time internal corruption destroy ground rule -- cheer kent',
#  'hitherto ye ask nothing name ask ye shall receive joy may full',
#  'well explain thing post socreligionislam attached quote bobby effect atheists lie evil scum ask commonly-held idea among muslim get response ask unknown guess karl -----------------------------------------------------------------------------',
#  'tradition church hold apostle mean 11 survive disciple matthias barnabas paul martyr except john tradition understood read early church writing bible heteroorthodox scripture',
#  'youre say mind make youll explain away difference statistically insignificant youll explain away inconsistancies theory special case equate re-read word study release 1991 find 11 female seagull lesbians apply last sentence theory notice contridicting observation dont know much math ability use sas determine length third side triangle fundemental geometry goal postulate one goal objectivenatural morality system propose survival specie homosexuality immoral',
#  'tdb 12 disease introduce brazilian oher sam tribes x million fair go happen eventually give time american would reach europe thing would happen matter get together first',
#  'point set view way believe say eveil world cause atheism ridiculous counterproductive dialogue newsgroups see post spirit condemnation atheist newsgroup bacause believe exactly youre try convert atheist youre fail miserably want position constantly defend agaist insult attack like seem like im sorry youre blind didnt get messgae quote everyone else seem']

# %%
test_processed = preprocess(test_df["text"])

# %% [markdown]
# ### Define text feature extractors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import metrics
from gensim.models import Word2Vec
from gensim.models import Doc2Vec
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
#takes processed Series as input
def TF_IDF(train, test):
    train_corpus = train.tolist()
    test_corpus = test.tolist()
    vectorizer = TfidfVectorizer()
    X_train = vectorizer.fit_transform(train_corpus).toarray()
    X_test = vectorizer.transform(test_corpus).toarray()
    return X_train, X_test

# %%
def CountVect(train, test):
    train_corpus = train.tolist()
    test_corpus = test.tolist()
    count_vect = CountVectorizer()
    X_train = count_vect.fit_transform(train_corpus)
    X_test = count_vect.transform(test_corpus)
    #print(X_train.shape[0])
    return X_train, X_test

# %%
def word2vect(train, test):
    
    #tokenize first
    train_corpus = train.apply(lambda text: nltk.word_tokenize(text))
    test_corpus = test.apply(lambda text: nltk.word_tokenize(text))
    corpus = train_corpus.tolist() + test_corpus.tolist()
    #len(corpus)
    model = Word2Vec()
    model.build_vocab(corpus)  # prepare the model vocabulary
    model.train(corpus, total_examples=model.corpus_count, epochs=model.epochs)  # train word vectors

    #model.wv.index_to_key
    #model.wv.most_similar("king")

    words = set(model.wv.index_to_key)
    
    X_train = train_corpus
    X_test = test_corpus
    
    arr=np.array([model.wv[i] for i in words])
    X_train_vect = np.array([arr for ls in X_train])
    X_test_vect = np.array([arr for ls in X_test])  

#     X_train_vect = np.array([np.array([model.wv[i] for i in ls if i in words]) for ls in X_train])
#     X_test_vect = np.array([np.array([model.wv[i] for i in ls if i in words]) for ls in X_test])  
           
    #Why is the length of the sentence different than the length of the sentence vector?
    # for i, v in enumerate(X_train_vect):
    #     print(len(X_train.iloc[i]), len(v))      

    # Compute sentence vectors by averaging the word vectors
           
    X_train_vect_avg = []
    for v in X_train_vect:
        if v.size:
            X_train_vect_avg.append(v.mean(axis=0))
        else:
            X_train_vect_avg.append(np.zeros(100, dtype=float))

    X_test_vect_avg = []
    for v in X_test_vect:
        if v.size:
            X_test_vect_avg.append(v.mean(axis=0))
        else:
            X_test_vect_avg.append(np.zeros(100, dtype=float))
    #for negaitve values
    scaler = MinMaxScaler()
    X_norm = scaler.fit_transform(X_train_vect_avg)
    X_test = scaler.transform(X_test_vect_avg)
    return X_norm, X_test

# %%
def doc2vect(train, test):
    
    #tokenize first
    train_corpus = train.apply(lambda text: nltk.word_tokenize(text))
    test_corpus = test.apply(lambda text: nltk.word_tokenize(text))
    corpus = train_corpus.tolist() + test_corpus.tolist()
    
    import multiprocessing
    num_cores = multiprocessing.cpu_count()
    from gensim.models.doc2vec import TaggedDocument,Doc2Vec

    documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(corpus)]
    model = Doc2Vec(documents,vector_size=5, window=2, min_count=1, workers=num_cores)
    model.build_vocab(documents)
    model.train(documents, total_examples=model.corpus_count,epochs=10)

    def vector_for_learning(model, input_docs):
        sents = input_docs
        targets, feature_vectors = zip(*[(doc.tags[0], model.infer_vector(doc.words)) for doc in sents])
        return targets, feature_vectors

    train_documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(train_corpus)]
    test_documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(test_corpus)]

    _, X_train = vector_for_learning(model, train_documents)
    _, X_test = vector_for_learning(model, test_documents)
     #for negaitve values
    scaler = MinMaxScaler()
    X_norm = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    return X_norm, X_test

# %% [markdown]
# ### Benchmarking with classifiers and feature extractors

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
feat_extractors = [TF_IDF, CountVect, word2vect, doc2vect]
classifiers = [MultinomialNB, LogisticRegression,svm.SVC, DecisionTreeClassifier]
for clf  in classifiers:
    results =[]
    for fn in feat_extractors:
        X_train, X_test = fn(train_processed, test_processed)
        model = clf()
        model.fit(X_train, train_data.target)
        pred = model.predict(X_test)
        score = accuracy_score(test_data.target, pred)
        #print(f"{clf.__name__} | {fn.__name__}  | {round(score, 3)} ")
        results.append(score)

    for fn, acc in zip(feat_extractors, results):
        print(f"For classifier: {clf.__name__} | feature extractor: {fn.__name__}  | Accuracy: {round(acc, 3)} ")
    print("\n")
# Out:
# For classifier: MultinomialNB | feature extractor: TF_IDF  | Accuracy: 0.633
# For classifier: MultinomialNB | feature extractor: CountVect  | Accuracy: 0.712
# For classifier: MultinomialNB | feature extractor: word2vect  | Accuracy: 0.56
# For classifier: MultinomialNB | feature extractor: doc2vect  | Accuracy: 0.561
#
#
# For classifier: LogisticRegression | feature extractor: TF_IDF  | Accuracy: 0.691
# For classifier: LogisticRegression | feature extractor: CountVect  | Accuracy: 0.668
# For classifier: LogisticRegression | feature extractor: word2vect  | Accuracy: 0.56
# For classifier: LogisticRegression | feature extractor: doc2vect  | Accuracy: 0.596
#
#
# For classifier: SVC | feature extractor: TF_IDF  | Accuracy: 0.684
# For classifier: SVC | feature extractor: CountVect  | Accuracy: 0.586
# For classifier: SVC | feature extractor: word2vect  | Accuracy: 0.56
# For classifier: SVC | feature extractor: doc2vect  | Accuracy: 0.596
#
#
# For classifier: DecisionTreeClassifier | feature extractor: TF_IDF  | Accuracy: 0.616
# For classifier: DecisionTreeClassifier | feature extractor: CountVect  | Accuracy: 0.575
# For classifier: DecisionTreeClassifier | feature extractor: word2vect  | Accuracy: 0.56
# For classifier: DecisionTreeClassifier | feature extractor: doc2vect  | Accuracy: 0.6
